# %%
from nilearn.plotting import plot_roi
from glob import glob

# %matplotlib inline

# %%
plot_roi("/Users/theresacheng/Documents/learning/neuroimaging/fmriRepro_UNC2017/data/", "/Users/theresacheng/Documents/learning/neuroimaging/fmriRepro_UNC2017/data/bids-test/sub-104/ses-wave1/anat/sub-104_ses-wave1_T1w.nii.gz")

# %%
for sub in glob("/Users/theresacheng/Documents/learning/neuroimaging/fmriRepro_UNC2017/data/ds000030_R1.0.5_2/derivatives/task/sub*/thresh*"):
    plot_roi(sub, cut_coords=(10,20,10))
# Out:
# //anaconda/lib/python3.6/site-packages/numpy/ma/core.py:4185: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")

# %%
plot_roi?
